# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None) # Display all rows
pd.set_option('display.max_columns', None) # Display all columns
pd.set_option('display.width', None) # Prevent wrapping
pd.set_option('display.max_colwidth', None) # Display full content of columns

# %%
df = pd.read_json('dummy input.json')

# %%
df.head()
# Out:
#     fin_year month  state_code     state_name  district_code district_name  \
# 0  2024-2025   Feb          31  UTTAR PRADESH           3109        BIJNOR
# 1  2024-2025   Feb          31  UTTAR PRADESH           3111        RAMPUR
# 2  2024-2025   Feb          31  UTTAR PRADESH           3112    SAHARANPUR
# 3  2024-2025   Feb          31  UTTAR PRADESH           3117   BULANDSHAHR
# 4  2024-2025   Feb          31  UTTAR PRADESH           3118       ALIGARH
#
#    Approved_Labour_Budget  Average_Wage_rate_per_day_per_person  \
# 0                 4617218                            236.922173
# 1                 3265228                            237.582183
# 2                 1513116                            241.894719
# 3                  442225                            235.835366
# 4                 2320974                            238.397853
#
#    Average_days_of_employment_provided_per_Household  \
# 0                                                 32
# ...

# %%
monthly_counts = df.groupby(['fin_year', 'month']).size().reset_index(name='entry_count')

# %%
monthly_counts
# Out:
#      fin_year  month  entry_count
# 0   2018-2019  April           35
# 1   2018-2019    Aug           13
# 2   2018-2019    Dec           22
# 3   2018-2019    Feb           13
# 4   2018-2019    Jan           17
# 5   2018-2019   July           16
# 6   2018-2019   June           31
# 7   2018-2019  March           15
# 8   2018-2019    May           22
# 9   2018-2019    Nov           16
# 10  2018-2019    Oct           19
# 11  2018-2019    Sep           30
# 12  2019-2020  April           20
# 13  2019-2020    Aug           20
# 14  2019-2020    Dec           11
# 15  2019-2020    Feb           28
# 16  2019-2020    Jan           15
# 17  2019-2020   July           14
# 18  2019-2020   June           18
# 19  2019-2020  March           22
# 20  2019-2020    May           16
# 21  2019-2020    Nov           14
# 22  2019-2020    Oct           15
# 23  2019-2020    Sep           16
# 24  2020-2021  April           12
# 25  2020-2021    Aug            7
# ...

# %%
db_new = pd.read_csv("mgnrega_export.csv")

# %%
new_monthly_counts = db_new.groupby(['fin_year', 'month']).size().reset_index(name='entry_count')

# %%
new_monthly_counts
# Out:
#      fin_year  month  entry_count
# 0   2018-2019  April           75
# 1   2018-2019    Aug           75
# 2   2018-2019    Dec           75
# 3   2018-2019    Feb           75
# 4   2018-2019    Jan           75
# 5   2018-2019   July           75
# 6   2018-2019   June           75
# 7   2018-2019  March           75
# 8   2018-2019    May           75
# 9   2018-2019    Nov           75
# 10  2018-2019    Oct           75
# 11  2018-2019    Sep           75
# 12  2019-2020    Aug           75
# 13  2019-2020    Dec           75
# 14  2019-2020    Feb           75
# 15  2019-2020    Jan           75
# 16  2019-2020   July           75
# 17  2019-2020   June           75
# 18  2019-2020  March           75
# 19  2019-2020    May           75
# 20  2019-2020    Nov           75
# 21  2019-2020    Oct           75
# 22  2019-2020    Sep           75
# 23  2020-2021  April           75
# 24  2020-2021    Aug           75
# 25  2020-2021    Dec           75
# ...
